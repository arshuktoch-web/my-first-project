# %% [markdown]
# ## Set -----> {}
#
# 1. set is a collection unique elements
# 2. set is unordered
# 3. set is unindexed
# 4. set is immutable

# %%
x = {"hello",78,67,9.7,'hi',67,67,67}

print(x)
# Out:
# {67, 'hi', 9.7, 'hello', 78}

# %%
x = {11,33,44,55}
x.add(78)
print(x)
# Out:
# {33, 11, 44, 78, 55}

# %%
x = {11,33,44,55}
x.update({"hello",78,"hi",90})
print(x)
# Out:
# {33, 11, 44, 'hello', 78, 'hi', 55, 90}

# %%
x = {1,2,3,4}
y = {1,5,6,4}

# x.update(y)
z = x.union(y)

print(x)
print(z)
# Out:
# {1, 2, 3, 4}
# {1, 2, 3, 4, 5, 6}

# %%
x = {1,2,3,4}
y = {1,5,6,4}

z = x.difference(y)
u = x - y

# print(x)
print(z)
print(u)
# Out:
# {2, 3}
# {2, 3}

# %%
x = {1,2,3,4}
y = {1,5,6,4}

# z = x.difference(y)
# z = x.symmetric_difference(y)
z = x.intersection(y)
# u = x - y

# print(x)
print(z)
# print(u)
# Out:
# {1, 4}

# %%
x = [1,2,3,4]
y = [1,3,4,7]

# output
# z = [2]
z = list(set(x)-set(y))
print(z)
# Out:
# [2]

# %%
x = "hello"
z = [x]
y = list(x)

print(z)
print(y)
# Out:
# ['hello']
# ['h', 'e', 'l', 'l', 'o']

# %%
x = "hello"
z = set(x)

print(z)
# Out:
# {'h', 'o', 'l', 'e'}

# %%
x = {11,22,33,44,55,22,22}

# x.remove(22)
# x.remove(66)
# x.discard(66)
# del x
# z = x.pop()
x.clear()
print(x)
# print(z)
# Out:
# set()

# %%
x = {1,2,3,4}
y = {1,2,3,4,5,6,7,8}

z = x.is
